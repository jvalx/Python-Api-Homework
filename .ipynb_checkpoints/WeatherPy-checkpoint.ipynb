# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/juanvalderrama/opt/anaconda3/lib/python3.8/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/juanvalderrama/opt/anaconda3/lib/python3.8/site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from sklearn import datasets
from datetime import date

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
new_cities = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"

print("Beginning Data Retrieval")   
print("-----------------------------")

record_count = 0
set_count = 1
for i in cities: 
    query_url = url + f"q={i}&appid={weather_api_key}&units=imperial"
    response = requests.get(query_url).json()

    
    if record_count > 49:
        record_count = 0
        set_count += 1
    else:
        record_count += 1
    
    print(f"Processing Record {record_count} of Set {set_count} | {i}")
    try: 
#         new_cities.append(i)
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        new_cities.append(i)
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | surt
# Processing Record 2 of Set 1 | fairbanks
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | ancud
# Processing Record 6 of Set 1 | gravenhurst
# Processing Record 7 of Set 1 | baherden
# Processing Record 8 of Set 1 | luderitz
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | nemuro
# Processing Record 12 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | avarua
# Processing Record 15 of Set 1 | college
# Processing Record 16 of Set 1 | provideniya
# Processing Record 17 of Set 1 | fort nelson
# Processing Record 18 of Set 1 | axim
# Processing Record 19 of Set 1 | pacific grove
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | portland
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | severo-kurilsk
# Processing Record 24 of Set 1 | pitsunda
# Processing Record 25 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | amqui
# Processing Record 28 of Set 1 | cidreira
# Processing Record 29 of Set 1 | moron
# Processing Record 30 of Set 1 | haines junction
# Processing Record 31 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | lebu
# Processing Record 35 of Set 1 | san patricio
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | formoso do araguaia
# City not found. Skipping...
# Processing Record 39 of Set 1 | namibe
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | saint-denis
# Processing Record 42 of Set 1 | torbay
# Processing Record 43 of Set 1 | yumen
# Processing Record 44 of Set 1 | burnie
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | palana
# Processing Record 47 of Set 1 | awjilah
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | george town
# Processing Record 50 of Set 1 | bambous virieux
# Processing Record 0 of Set 2 | georgetown
# Processing Record 1 of Set 2 | sharya
# Processing Record 2 of Set 2 | cape town
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | leningradskiy
# Processing Record 6 of Set 2 | east london
# Processing Record 7 of Set 2 | kruisfontein
# Processing Record 8 of Set 2 | souillac
# Processing Record 9 of Set 2 | clyde river
# Processing Record 10 of Set 2 | shimoda
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | padang
# Processing Record 13 of Set 2 | tawang
# Processing Record 14 of Set 2 | port macquarie
# Processing Record 15 of Set 2 | boljarovo
# City not found. Skipping...
# Processing Record 16 of Set 2 | norman wells
# Processing Record 17 of Set 2 | nikolskoye
# Processing Record 18 of Set 2 | komsomolskiy
# Processing Record 19 of Set 2 | pitimbu
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | cayenne
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | barcarena
# Processing Record 24 of Set 2 | bonavista
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | lasa
# Processing Record 27 of Set 2 | kavieng
# Processing Record 28 of Set 2 | new norfolk
# Processing Record 29 of Set 2 | murmansk
# Processing Record 30 of Set 2 | victoria point
# Processing Record 31 of Set 2 | katsuura
# Processing Record 32 of Set 2 | fort morgan
# Processing Record 33 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 34 of Set 2 | altay
# Processing Record 35 of Set 2 | macaboboni
# City not found. Skipping...
# Processing Record 36 of Set 2 | vylgort
# City not found. Skipping...
# Processing Record 37 of Set 2 | qaanaaq
# Processing Record 38 of Set 2 | saldanha
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | alihe
# Processing Record 41 of Set 2 | desaguadero
# Processing Record 42 of Set 2 | sao filipe
# Processing Record 43 of Set 2 | codrington
# Processing Record 44 of Set 2 | vestmannaeyjar
# Processing Record 45 of Set 2 | coihaique
# Processing Record 46 of Set 2 | sredec
# City not found. Skipping...
# Processing Record 47 of Set 2 | barrow
# Processing Record 48 of Set 2 | geraldton
# Processing Record 49 of Set 2 | muros
# Processing Record 50 of Set 2 | rio gallegos
# Processing Record 0 of Set 3 | aklavik
# Processing Record 1 of Set 3 | eyrarbakki
# Processing Record 2 of Set 3 | tiksi
# Processing Record 3 of Set 3 | narsaq
# Processing Record 4 of Set 3 | sitka
# Processing Record 5 of Set 3 | bredasdorp
# Processing Record 6 of Set 3 | richards bay
# Processing Record 7 of Set 3 | ponta do sol
# Processing Record 8 of Set 3 | albany
# Processing Record 9 of Set 3 | kodiak
# Processing Record 10 of Set 3 | cabra
# Processing Record 11 of Set 3 | tocopilla
# Processing Record 12 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 3 | jibuti
# Processing Record 14 of Set 3 | dom pedro
# Processing Record 15 of Set 3 | meulaboh
# Processing Record 16 of Set 3 | walvis bay
# Processing Record 17 of Set 3 | hambantota
# Processing Record 18 of Set 3 | ewa beach
# Processing Record 19 of Set 3 | tucuma
# Processing Record 20 of Set 3 | necochea
# Processing Record 21 of Set 3 | nebug
# Processing Record 22 of Set 3 | hithadhoo
# Processing Record 23 of Set 3 | thinadhoo
# Processing Record 24 of Set 3 | vila
# Processing Record 25 of Set 3 | wewak
# Processing Record 26 of Set 3 | micheweni
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | saint-pierre
# Processing Record 29 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 3 | benghazi
# Processing Record 31 of Set 3 | kapit
# Processing Record 32 of Set 3 | sept-iles
# Processing Record 33 of Set 3 | port elizabeth
# Processing Record 34 of Set 3 | paamiut
# Processing Record 35 of Set 3 | ribeira grande
# Processing Record 36 of Set 3 | half moon bay
# Processing Record 37 of Set 3 | samarai
# Processing Record 38 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 3 | mananjary
# Processing Record 40 of Set 3 | castro
# Processing Record 41 of Set 3 | mutoko
# Processing Record 42 of Set 3 | preobrazheniye
# Processing Record 43 of Set 3 | uige
# Processing Record 44 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 3 | baruun-urt
# Processing Record 46 of Set 3 | praia da vitoria
# Processing Record 47 of Set 3 | port hedland
# Processing Record 48 of Set 3 | suyo
# Processing Record 49 of Set 3 | faanui
# Processing Record 50 of Set 3 | chokurdakh
# Processing Record 0 of Set 4 | oktyabrskoye
# Processing Record 1 of Set 4 | songkhla
# Processing Record 2 of Set 4 | jacmel
# Processing Record 3 of Set 4 | garissa
# Processing Record 4 of Set 4 | shangqiu
# Processing Record 5 of Set 4 | ilulissat
# Processing Record 6 of Set 4 | avera
# Processing Record 7 of Set 4 | twentynine palms
# Processing Record 8 of Set 4 | semnan
# Processing Record 9 of Set 4 | bemidji
# Processing Record 10 of Set 4 | saint-augustin
# Processing Record 11 of Set 4 | stokmarknes
# Processing Record 12 of Set 4 | touros
# Processing Record 13 of Set 4 | hobart
# Processing Record 14 of Set 4 | victoria
# Processing Record 15 of Set 4 | eldikan
# City not found. Skipping...
# Processing Record 16 of Set 4 | airai
# Processing Record 17 of Set 4 | hobyo
# Processing Record 18 of Set 4 | pisco
# Processing Record 19 of Set 4 | dosso
# Processing Record 20 of Set 4 | beloha
# Processing Record 21 of Set 4 | pevek
# Processing Record 22 of Set 4 | brae
# Processing Record 23 of Set 4 | santa marta
# Processing Record 24 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 4 | hearst
# Processing Record 26 of Set 4 | carutapera
# Processing Record 27 of Set 4 | san cristobal
# Processing Record 28 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 4 | ouesso
# Processing Record 30 of Set 4 | sikasso
# Processing Record 31 of Set 4 | rosario de mora
# Processing Record 32 of Set 4 | manggar
# Processing Record 33 of Set 4 | nuuk
# Processing Record 34 of Set 4 | kuandian
# Processing Record 35 of Set 4 | linxia
# Processing Record 36 of Set 4 | sylva
# Processing Record 37 of Set 4 | chhabra
# Processing Record 38 of Set 4 | hamilton
# Processing Record 39 of Set 4 | cockburn town
# Processing Record 40 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 4 | svetlogorsk
# Processing Record 42 of Set 4 | saint-leu
# Processing Record 43 of Set 4 | jiancheng
# Processing Record 44 of Set 4 | trat
# Processing Record 45 of Set 4 | svetlaya
# Processing Record 46 of Set 4 | dikson
# Processing Record 47 of Set 4 | moses lake
# Processing Record 48 of Set 4 | ipiales
# Processing Record 49 of Set 4 | plymouth
# Processing Record 50 of Set 4 | hastings
# Processing Record 0 of Set 5 | bereznik
# Processing Record 1 of Set 5 | mount isa
# Processing Record 2 of Set 5 | kidal
# Processing Record 3 of Set 5 | san policarpo
# Processing Record 4 of Set 5 | atasu
# Processing Record 5 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 5 | moche
# Processing Record 7 of Set 5 | rawson
# Processing Record 8 of Set 5 | fergus falls
# Processing Record 9 of Set 5 | santa maria
# Processing Record 10 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 11 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 12 of Set 5 | anchorage
# Processing Record 13 of Set 5 | damavand
# Processing Record 14 of Set 5 | longyearbyen
# Processing Record 15 of Set 5 | tadine
# Processing Record 16 of Set 5 | guelavia
# City not found. Skipping...
# Processing Record 17 of Set 5 | khor
# Processing Record 18 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 5 | makakilo city
# Processing Record 20 of Set 5 | kaitangata
# Processing Record 21 of Set 5 | inhambane
# Processing Record 22 of Set 5 | segezha
# Processing Record 23 of Set 5 | broome
# Processing Record 24 of Set 5 | chippewa falls
# Processing Record 25 of Set 5 | longmeadow
# Processing Record 26 of Set 5 | turayf
# Processing Record 27 of Set 5 | mackay
# Processing Record 28 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 29 of Set 5 | bethel
# Processing Record 30 of Set 5 | karratha
# Processing Record 31 of Set 5 | maniitsoq
# Processing Record 32 of Set 5 | dianopolis
# City not found. Skipping...
# Processing Record 33 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 5 | arraial do cabo
# Processing Record 35 of Set 5 | quelimane
# Processing Record 36 of Set 5 | bontang
# Processing Record 37 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 5 | tuatapere
# Processing Record 39 of Set 5 | gao
# Processing Record 40 of Set 5 | aquiraz
# Processing Record 41 of Set 5 | kirakira
# Processing Record 42 of Set 5 | vestmanna
# Processing Record 43 of Set 5 | aleksandrov gay
# Processing Record 44 of Set 5 | talnakh
# Processing Record 45 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 5 | fallon
# Processing Record 47 of Set 5 | sakaiminato
# Processing Record 48 of Set 5 | roald
# Processing Record 49 of Set 5 | guadalajara
# Processing Record 50 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 0 of Set 6 | blagodatnoye
# Processing Record 1 of Set 6 | launceston
# Processing Record 2 of Set 6 | sahrak
# City not found. Skipping...
# Processing Record 3 of Set 6 | san andres
# Processing Record 4 of Set 6 | olafsvik
# Processing Record 5 of Set 6 | mitsamiouli
# Processing Record 6 of Set 6 | coquimbo
# Processing Record 7 of Set 6 | ponta delgada
# Processing Record 8 of Set 6 | polyarnyy
# Processing Record 9 of Set 6 | bose
# Processing Record 10 of Set 6 | vicuna
# Processing Record 11 of Set 6 | port hardy
# Processing Record 12 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 6 | chiang rai
# Processing Record 14 of Set 6 | nishihara
# Processing Record 15 of Set 6 | vysoke myto
# Processing Record 16 of Set 6 | jacareacanga
# Processing Record 17 of Set 6 | fortuna
# Processing Record 18 of Set 6 | atar
# Processing Record 19 of Set 6 | yenagoa
# Processing Record 20 of Set 6 | iqaluit
# Processing Record 21 of Set 6 | maningrida
# Processing Record 22 of Set 6 | batagay-alyta
# Processing Record 23 of Set 6 | manzil tamim
# City not found. Skipping...
# Processing Record 24 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 6 | bowen
# Processing Record 26 of Set 6 | caravelas
# Processing Record 27 of Set 6 | tual
# Processing Record 28 of Set 6 | buraydah
# Processing Record 29 of Set 6 | los llanos de aridane
# Processing Record 30 of Set 6 | russell
# Processing Record 31 of Set 6 | sibu
# Processing Record 32 of Set 6 | sambava
# Processing Record 33 of Set 6 | yurimaguas
# Processing Record 34 of Set 6 | khatanga
# Processing Record 35 of Set 6 | kaeo
# Processing Record 36 of Set 6 | northam
# Processing Record 37 of Set 6 | north bend
# Processing Record 38 of Set 6 | guerrero negro
# Processing Record 39 of Set 6 | bengkulu
# Processing Record 40 of Set 6 | cherskiy
# Processing Record 41 of Set 6 | murgab
# Processing Record 42 of Set 6 | khonsa
# Processing Record 43 of Set 6 | kibala
# Processing Record 44 of Set 6 | mareeba
# Processing Record 45 of Set 6 | iwanai
# Processing Record 46 of Set 6 | sukumo
# Processing Record 47 of Set 6 | walsrode
# Processing Record 48 of Set 6 | praia
# Processing Record 49 of Set 6 | broken hill
# Processing Record 50 of Set 6 | sulangan
# Processing Record 0 of Set 7 | kamenka
# Processing Record 1 of Set 7 | maldonado
# Processing Record 2 of Set 7 | kloulklubed
# Processing Record 3 of Set 7 | yushu
# Processing Record 4 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 7 | sao joao da barra
# Processing Record 6 of Set 7 | kambarka
# Processing Record 7 of Set 7 | grand forks
# Processing Record 8 of Set 7 | nogales
# Processing Record 9 of Set 7 | ostersund
# Processing Record 10 of Set 7 | kotli loharan
# Processing Record 11 of Set 7 | tsumeb
# Processing Record 12 of Set 7 | sarankhola
# Processing Record 13 of Set 7 | mehamn
# Processing Record 14 of Set 7 | tautira
# Processing Record 15 of Set 7 | pilar
# Processing Record 16 of Set 7 | shieli
# Processing Record 17 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 18 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 7 | saskylakh
# Processing Record 20 of Set 7 | shenjiamen
# Processing Record 21 of Set 7 | henties bay
# Processing Record 22 of Set 7 | dera bugti
# Processing Record 23 of Set 7 | chuy
# Processing Record 24 of Set 7 | verkhnevilyuysk
# Processing Record 25 of Set 7 | podgorica
# Processing Record 26 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 27 of Set 7 | concarneau
# Processing Record 28 of Set 7 | nizhnyaya tavda
# Processing Record 29 of Set 7 | taoudenni
# Processing Record 30 of Set 7 | morgan city
# Processing Record 31 of Set 7 | mar del plata
# Processing Record 32 of Set 7 | tavagnacco
# Processing Record 33 of Set 7 | ratnagiri
# Processing Record 34 of Set 7 | kozan
# Processing Record 35 of Set 7 | bairiki
# Processing Record 36 of Set 7 | villa rica
# Processing Record 37 of Set 7 | ulaangom
# Processing Record 38 of Set 7 | coro
# Processing Record 39 of Set 7 | kudahuvadhoo
# Processing Record 40 of Set 7 | camocim de sao felix
# Processing Record 41 of Set 7 | aravankadu
# Processing Record 42 of Set 7 | san carlos de bariloche
# Processing Record 43 of Set 7 | nanortalik
# Processing Record 44 of Set 7 | grindavik
# Processing Record 45 of Set 7 | jizan
# Processing Record 46 of Set 7 | nhulunbuy
# Processing Record 47 of Set 7 | darque
# Processing Record 48 of Set 7 | tingrela
# City not found. Skipping...
# Processing Record 49 of Set 7 | quatre cocos
# Processing Record 50 of Set 7 | astipalaia
# City not found. Skipping...
# Processing Record 0 of Set 8 | turukhansk
# Processing Record 1 of Set 8 | ozark
# Processing Record 2 of Set 8 | okha
# Processing Record 3 of Set 8 | griffith
# Processing Record 4 of Set 8 | constitucion
# Processing Record 5 of Set 8 | jalu
# Processing Record 6 of Set 8 | camocim
# Processing Record 7 of Set 8 | udachnyy
# Processing Record 8 of Set 8 | marystown
# Processing Record 9 of Set 8 | lompoc
# Processing Record 10 of Set 8 | qaqortoq
# Processing Record 11 of Set 8 | bathsheba
# Processing Record 12 of Set 8 | kombotion
# City not found. Skipping...
# Processing Record 13 of Set 8 | hovd
# Processing Record 14 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 8 | olden
# Processing Record 16 of Set 8 | aripuana
# Processing Record 17 of Set 8 | acapulco
# Processing Record 18 of Set 8 | sukhumi
# Processing Record 19 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 8 | dali
# Processing Record 21 of Set 8 | moussoro
# Processing Record 22 of Set 8 | kupang
# Processing Record 23 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 24 of Set 8 | barkly west
# Processing Record 25 of Set 8 | bardiyah
# Processing Record 26 of Set 8 | prince george
# Processing Record 27 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 28 of Set 8 | gairo
# Processing Record 29 of Set 8 | kalmunai
# Processing Record 30 of Set 8 | joacaba
# Processing Record 31 of Set 8 | nome
# Processing Record 32 of Set 8 | hasaki
# Processing Record 33 of Set 8 | abu kamal
# Processing Record 34 of Set 8 | yulara
# Processing Record 35 of Set 8 | muroto
# Processing Record 36 of Set 8 | mafinga
# Processing Record 37 of Set 8 | cap malheureux
# Processing Record 38 of Set 8 | anadyr
# Processing Record 39 of Set 8 | tura
# Processing Record 40 of Set 8 | hami
# Processing Record 41 of Set 8 | shubarshi
# Processing Record 42 of Set 8 | lufkin
# Processing Record 43 of Set 8 | olinda
# Processing Record 44 of Set 8 | marsa matruh
# Processing Record 45 of Set 8 | macedo de cavaleiros
# Processing Record 46 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 8 | lavrentiya
# Processing Record 48 of Set 8 | bluffton
# Processing Record 49 of Set 8 | kamskiye polyany
# Processing Record 50 of Set 8 | ust-nera
# Processing Record 0 of Set 9 | esperance
# Processing Record 1 of Set 9 | senneterre
# Processing Record 2 of Set 9 | sao felix do xingu
# Processing Record 3 of Set 9 | te anau
# Processing Record 4 of Set 9 | gollere
# City not found. Skipping...
# Processing Record 5 of Set 9 | peniche
# Processing Record 6 of Set 9 | blagoyevo
# Processing Record 7 of Set 9 | wagga wagga
# Processing Record 8 of Set 9 | gamba
# Processing Record 9 of Set 9 | witu
# Processing Record 10 of Set 9 | tarakan
# Processing Record 11 of Set 9 | shingu
# Processing Record 12 of Set 9 | kaili
# Processing Record 13 of Set 9 | arman
# Processing Record 14 of Set 9 | laiyang
# Processing Record 15 of Set 9 | redding
# Processing Record 16 of Set 9 | naryan-mar
# Processing Record 17 of Set 9 | pangnirtung
# Processing Record 18 of Set 9 | humaita
# Processing Record 19 of Set 9 | guiglo
# Processing Record 20 of Set 9 | madang
# Processing Record 21 of Set 9 | yinchuan
# Processing Record 22 of Set 9 | zeya
# Processing Record 23 of Set 9 | ola
# Processing Record 24 of Set 9 | mporokoso
# Processing Record 25 of Set 9 | gizo
# Processing Record 26 of Set 9 | zhucheng
# Processing Record 27 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 9 | tongliao
# Processing Record 29 of Set 9 | sydney
# Processing Record 30 of Set 9 | linares
# Processing Record 31 of Set 9 | la ronge
# Processing Record 32 of Set 9 | maceio
# Processing Record 33 of Set 9 | pimentel
# Processing Record 34 of Set 9 | roebourne
# Processing Record 35 of Set 9 | lagoa
# Processing Record 36 of Set 9 | adra
# Processing Record 37 of Set 9 | jamsa
# Processing Record 38 of Set 9 | bayir
# Processing Record 39 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 9 | harper
# Processing Record 41 of Set 9 | yuanping
# Processing Record 42 of Set 9 | rocha
# Processing Record 43 of Set 9 | lazaro cardenas
# Processing Record 44 of Set 9 | karlskrona
# Processing Record 45 of Set 9 | martuni
# Processing Record 46 of Set 9 | karpathos
# Processing Record 47 of Set 9 | puerto escondido
# Processing Record 48 of Set 9 | byron bay
# Processing Record 49 of Set 9 | guozhen
# Processing Record 50 of Set 9 | churapcha
# Processing Record 0 of Set 10 | urucara
# Processing Record 1 of Set 10 | amazar
# Processing Record 2 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 3 of Set 10 | kutum
# Processing Record 4 of Set 10 | kantunilkin
# Processing Record 5 of Set 10 | kavaratti
# Processing Record 6 of Set 10 | diapaga
# Processing Record 7 of Set 10 | macamic
# Processing Record 8 of Set 10 | omboue
# Processing Record 9 of Set 10 | aykhal
# Processing Record 10 of Set 10 | tiarei
# Processing Record 11 of Set 10 | alofi
# Processing Record 12 of Set 10 | ornskoldsvik
# Processing Record 13 of Set 10 | emba
# Processing Record 14 of Set 10 | trelew
# Processing Record 15 of Set 10 | trinidad
# Processing Record 16 of Set 10 | whitecourt
# Processing Record 17 of Set 10 | nakamura
# Processing Record 18 of Set 10 | weihai
# Processing Record 19 of Set 10 | homer
# Processing Record 20 of Set 10 | hokitika
# Processing Record 21 of Set 10 | north platte
# Processing Record 22 of Set 10 | san blas
# Processing Record 23 of Set 10 | beyneu
# Processing Record 24 of Set 10 | vanimo
# Processing Record 25 of Set 10 | namie
# Processing Record 26 of Set 10 | cawayan
# Processing Record 27 of Set 10 | ilek
# Processing Record 28 of Set 10 | lannion
# Processing Record 29 of Set 10 | effingham
# Processing Record 30 of Set 10 | berlevag
# Processing Record 31 of Set 10 | curvelo
# Processing Record 32 of Set 10 | southbridge
# Processing Record 33 of Set 10 | champua
# Processing Record 34 of Set 10 | rauma
# Processing Record 35 of Set 10 | labuan
# Processing Record 36 of Set 10 | neuquen
# Processing Record 37 of Set 10 | carmen
# Processing Record 38 of Set 10 | tibati
# Processing Record 39 of Set 10 | ayan
# Processing Record 40 of Set 10 | chamba
# Processing Record 41 of Set 10 | floresta
# Processing Record 42 of Set 10 | karatau
# Processing Record 43 of Set 10 | toora-khem
# Processing Record 44 of Set 10 | jalalpur
# Processing Record 45 of Set 10 | rio grande
# Processing Record 46 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 47 of Set 10 | kudymkar
# Processing Record 48 of Set 10 | puerto carreno
# Processing Record 49 of Set 10 | yar-sale
# Processing Record 50 of Set 10 | merauke
# Processing Record 0 of Set 11 | sao joao do piaui
# Processing Record 1 of Set 11 | dajal
# Processing Record 2 of Set 11 | mweka
# Processing Record 3 of Set 11 | shambu
# Processing Record 4 of Set 11 | yebaishou
# Processing Record 5 of Set 11 | vila franca do campo
# Processing Record 6 of Set 11 | barroso
# Processing Record 7 of Set 11 | ebano
# City not found. Skipping...
# Processing Record 8 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 11 | dunedin
# Processing Record 10 of Set 11 | san quintin
# Processing Record 11 of Set 11 | daru
# Processing Record 12 of Set 11 | berezovyy
# Processing Record 13 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 11 | leh
# Processing Record 15 of Set 11 | waynesville
# Processing Record 16 of Set 11 | santa cruz cabralia
# Processing Record 17 of Set 11 | sao francisco de assis
# Processing Record 18 of Set 11 | erzin
# Processing Record 19 of Set 11 | lata
# Processing Record 20 of Set 11 | oni
# Processing Record 21 of Set 11 | robertsport
# Processing Record 22 of Set 11 | general pico
# Processing Record 23 of Set 11 | saint andrews
# Processing Record 24 of Set 11 | viedma
# Processing Record 25 of Set 11 | los angeles
# Processing Record 26 of Set 11 | kenora
# Processing Record 27 of Set 11 | dongsheng
# Processing Record 28 of Set 11 | aranos
# Processing Record 29 of Set 11 | igrim
# Processing Record 30 of Set 11 | dudinka
# Processing Record 31 of Set 11 | pali
# Processing Record 32 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 33 of Set 11 | alyangula
# Processing Record 34 of Set 11 | dingle
# Processing Record 35 of Set 11 | sinnamary
# Processing Record 36 of Set 11 | mount gambier
# Processing Record 37 of Set 11 | sant feliu de guixols
# Processing Record 38 of Set 11 | faya
# Processing Record 39 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 11 | nefteyugansk
# Processing Record 41 of Set 11 | slave lake
# Processing Record 42 of Set 11 | corowa
# Processing Record 43 of Set 11 | bilma
# Processing Record 44 of Set 11 | pedinon
# Processing Record 45 of Set 11 | alcudia
# Processing Record 46 of Set 11 | weiser
# Processing Record 47 of Set 11 | carnarvon
# Processing Record 48 of Set 11 | hanmer springs
# Processing Record 49 of Set 11 | acarau
# Processing Record 50 of Set 11 | sabha
# Processing Record 0 of Set 12 | kodinsk
# Processing Record 1 of Set 12 | sarai naurang
# Processing Record 2 of Set 12 | dicabisagan
# Processing Record 3 of Set 12 | hajdusamson
# Processing Record 4 of Set 12 | makat
# Processing Record 5 of Set 12 | susangerd
# Processing Record 6 of Set 12 | pavilosta
# Processing Record 7 of Set 12 | havelock
# Processing Record 8 of Set 12 | belaya gora
# Processing Record 9 of Set 12 | corn island
# Processing Record 10 of Set 12 | mayumba
# Processing Record 11 of Set 12 | yendi
# Processing Record 12 of Set 12 | tilichiki
# Processing Record 13 of Set 12 | mehran
# Processing Record 14 of Set 12 | gualdo tadino
# Processing Record 15 of Set 12 | ninghai
# Processing Record 16 of Set 12 | hofn
# Processing Record 17 of Set 12 | olga
# Processing Record 18 of Set 12 | deputatskiy
# Processing Record 19 of Set 12 | barra patuca
# Processing Record 20 of Set 12 | selikhino
# Processing Record 21 of Set 12 | sisimiut
# Processing Record 22 of Set 12 | chapais
# Processing Record 23 of Set 12 | poum
# Processing Record 24 of Set 12 | ekhabi
# Processing Record 25 of Set 12 | beringovskiy
# Processing Record 26 of Set 12 | benguela
# Processing Record 27 of Set 12 | dipkarpaz
# City not found. Skipping...
# Processing Record 28 of Set 12 | aswan
# Processing Record 29 of Set 12 | acajutla
# Processing Record 30 of Set 12 | gandai
# Processing Record 31 of Set 12 | sinjar
# Processing Record 32 of Set 12 | maralal
# Processing Record 33 of Set 12 | saint george
# Processing Record 34 of Set 12 | itaituba
# Processing Record 35 of Set 12 | ginda
# Processing Record 36 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 37 of Set 12 | abilene
# Processing Record 38 of Set 12 | isangel
# Processing Record 39 of Set 12 | klaksvik
# Processing Record 40 of Set 12 | caxito
# Processing Record 41 of Set 12 | asfi
# Processing Record 42 of Set 12 | carlyle
# Processing Record 43 of Set 12 | fort-shevchenko
# Processing Record 44 of Set 12 | tabou
# Processing Record 45 of Set 12 | una
# Processing Record 46 of Set 12 | aberdeen
# Processing Record 47 of Set 12 | shakawe
# Processing Record 48 of Set 12 | cabedelo
# Processing Record 49 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 50 of Set 12 | juneau
# Processing Record 0 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 1 of Set 13 | abu dhabi
# Processing Record 2 of Set 13 | severodvinsk
# Processing Record 3 of Set 13 | kulu
# Processing Record 4 of Set 13 | vreed en hoop
# City not found. Skipping...
# Processing Record 5 of Set 13 | hualmay
# Processing Record 6 of Set 13 | pauini
# Processing Record 7 of Set 13 | tselinnoye
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": new_cities,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date,
}
weather_df = pd.DataFrame.from_dict(weather_dict)
weather_df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            surt  31.2089   16.5887     81.46        41           0
# 1       fairbanks  64.8378 -147.7164     77.59        49          40
# 2       busselton -33.6500  115.3333     59.04        71         100
# 3        hermanus -34.4187   19.2345     57.79        80         100
# 4           ancud -41.8697  -73.8203     44.42        94         100
# ..            ...      ...       ...       ...       ...         ...
# 555  severodvinsk  64.5635   39.8302     69.91        87          73
# 556          kulu  39.0951   33.0799     62.44        68           7
# 557       hualmay -11.0964  -77.6139     63.75        87          37
# 558        pauini  -7.7136  -66.9764     76.78        75         100
# 559    tselinnoye  53.0833   85.6667     51.10        96         100
#
#      Wind Speed Country        Date
# 0          9.95      LY  1624417981
# 1          5.75      US  1624417843
# 2         10.09      AU  1624417981
# 3         15.59      ZA  1624417746
# 4          7.02      CL  1624417982
# ..          ...     ...         ...
# 555        8.23      RU  1624418154
# 556        4.23      TR  1624418154
# 557       12.41      PE  1624418155
# 558        2.26      BR  1624418155
# 559       13.04      RU  1624418155
#
# [560 rows x 9 columns]

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  560.000000  560.000000  560.000000  560.000000  560.000000  560.000000
# mean    20.788647   18.049545   68.020089   69.350000   53.744643    7.365786
# std     33.534224   90.709750   13.804696   20.438371   40.660655    5.050052
# min    -54.800000 -175.200000   31.950000   11.000000    0.000000    0.000000
# 25%     -7.479475  -58.931775   57.220000   59.000000    6.000000    3.552500
# 50%     29.628550   20.053500   69.835000   74.000000   67.500000    6.510000
# 75%     47.868775   99.983350   78.765000   84.250000   96.000000   10.090000
# max     78.218600  179.316700  100.060000  100.000000  100.000000   27.290000
#
#                Date
# count  5.600000e+02
# mean   1.624418e+09
# std    1.537271e+02
# min    1.624417e+09
# 25%    1.624418e+09
# 50%    1.624418e+09
# 75%    1.624418e+09
# max    1.624418e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
above_100H = list(weather_df.loc[weather_df['Humidity'] > 100].index)
above_100H
# Out:
# []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_df.loc[weather_df['Humidity'] <= 100]
clean_city_data
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            surt  31.2089   16.5887     81.46        41           0
# 1       fairbanks  64.8378 -147.7164     77.59        49          40
# 2       busselton -33.6500  115.3333     59.04        71         100
# 3        hermanus -34.4187   19.2345     57.79        80         100
# 4           ancud -41.8697  -73.8203     44.42        94         100
# ..            ...      ...       ...       ...       ...         ...
# 555  severodvinsk  64.5635   39.8302     69.91        87          73
# 556          kulu  39.0951   33.0799     62.44        68           7
# 557       hualmay -11.0964  -77.6139     63.75        87          37
# 558        pauini  -7.7136  -66.9764     76.78        75         100
# 559    tselinnoye  53.0833   85.6667     51.10        96         100
#
#      Wind Speed Country        Date
# 0          9.95      LY  1624417981
# 1          5.75      US  1624417843
# 2         10.09      AU  1624417981
# 3         15.59      ZA  1624417746
# 4          7.02      CL  1624417982
# ..          ...     ...         ...
# 555        8.23      RU  1624418154
# 556        4.23      TR  1624418154
# 557       12.41      PE  1624418155
# 558        2.26      BR  1624418155
# 559       13.04      RU  1624418155
#
# [560 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
today_date = date.today().strftime("%m/%d/%y")
weather_df.plot(kind='scatter', x='Lat', y='Max Temp', c='DarkBlue')
plt.title(f'City Latitude Vs Max Temperature ({today_date})')
plt.xlabel('Latitude')
plt.ylabel('Max temperature (F)')
plt.grid()
plt.savefig("../Images/LatitudeVsTemperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
weather_df.plot(kind='scatter', x='Lat', y='Humidity', c='DarkBlue')
plt.title(f'City Latitude Vs Max Temperature ({today_date})')
plt.xlabel('Latitude')
plt.ylabel('Max temperature (F)')
plt.grid()
plt.savefig("../Images/LatitudeVsTemperature.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
weather_df.plot(kind='scatter', x='Lat', y='Cloudiness', c='Red')
plt.title(f'City Latitude Vs Cloudiness ({today_date})')
plt.xlabel('Latitude')
plt.ylabel('Max temperature (F)')
plt.grid()
plt.savefig("../Images/LatitudeVsTemperature.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
weather_df.plot(kind='scatter', x='Lat', y='Wind Speed', c='DarkBlue')
plt.title(f'City Latitude Vs Wind Speed ({today_date})')
plt.xlabel('Latitude')
plt.ylabel('Max temperature (F)')
plt.grid()
plt.savefig("../Images/LatitudeVsTemperature.png")

# %%
weather_df.plot(kind='scatter', x='Lat', y='Wind Speed', c='DarkBlue')
plt.title(f'City Latitude Vs Max Temperature ()')
plt.xlabel('Latitude')
plt.ylabel('Max temperature (F)')
plt.grid()
plt.savefig("../Images/LatitudeVsTemperature.png")

# %% [markdown]
# ## Linear Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen


x_values = weather_df['Lat']
y_values = weather_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-value is: {rvalue}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

plt.show()
# Out:
# The r-value is: -0.023997774243633595

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
